# %% [markdown]
# # Scraping German train stations

# %% [markdown]
# The aim of this project is to automatize scraping informations about departures and arrivals from particular train station in Germany. In order to do this we will use following website - "https://bahnauskunft.info". Page "https://bahnauskunft.info/bahnhoefe-deutschland/" provides information about every train station in Germany. After clicking one of them and scrolling down you will see two tables which we want to scrap.

# %% [markdown]
# Although there are many webscraping tools to complete this project we will use Selenium because this website uses JavaScript to display datatables and requires clicking and selecting content before scraping.

# %%
import datetime
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.support.ui import Select
import pickle

driver = webdriver.Safari()

# %% [markdown]
# ## Stations dictionary

# %% [markdown]
# To scrap informations about train station we need to have their name and link redirecting to this train station website. The following code scraps informations about every train station name and link redirecting to their page. The only one disadvantage is that process takes a few minutes( so by default I've hashed this part of code) and to speed up I've already downloaded this data and stored them as dictionary { "name_of_station" : link } in file called 'stations_dictionary.pkl'. If you want to scrap them by your own unhash following code.

# %%
# website = "https://bahnauskunft.info/bahnhoefe-deutschland/"
# driver.get(website)

# %%
# cookie_button = driver.find_element_by_xpath('//*[@id="BorlabsCookieBox"]/div/div/div/div[1]/div/div/div[2]/p[1]/a') 
# driver.execute_script("arguments[0].click();", cookie_button)

# %%
# stations_dictionary = {}
# stations = driver.find_elements_by_class_name('wp-show-posts-entry-title')
# for station in stations:
#     stations_dictionary[station.find_element_by_tag_name('a').text] = station.find_element_by_tag_name('a').get_attribute('href')
#     
# del stations_dictionary["Deutsche Bahn Fahrplan"]
# del stations_dictionary["Fahrgastrechte Bahn"]
# del stations_dictionary["Deutsche Bahn Sitzplatzreservierung"]
# del stations_dictionary["Deutsche Bahn WLAN"]
# del stations_dictionary["ICE Sprinter"]
# del stations_dictionary["Deutsche Bahn mit Kindern"]

# %% [markdown]
# To load the dictionary we will use pickle package.

# %%
with open('stations_dictionary.pkl', 'rb') as dict:
    stations_dictionary = pickle.load(dict)

# %% [markdown]
# Let's see all available options to choose from.

# %%
print("List of " + str(len(stations_dictionary)) +" available stations\n")
print(stations_dictionary.keys())
# Out:
# List of 5392 available stations
#
# dict_keys(['Aachen Hauptbahnhof', 'Aachen Schanz', 'Aachen West', 'Aachen-Rothe Erde', 'Aalen Hauptbahnhof', 'Abensberg', 'Achern', 'Achim', 'Achmer', 'Achterwehr', 'Adelebsen', 'Adelschlag', 'Adelsdorf (Mittelfranken)', 'Adelsheim Nord', 'Adelsheim Ost', 'Adorf (Vogtland)', 'Affaltrach', 'Agatharied', 'Agathenburg', 'Aglasterhausen', 'Aha', 'Ahaus', 'Ahlen (Westfalen)', 'Ahlhorn', 'Ahlten (Hannover)', 'Ahrbrück', 'Ahrensburg', 'Ahrensburg-Gartenholz', 'Ahrensfelde', 'Ahrensfelde Friedhof', 'Ahrensfelde Nord', 'Ahrweiler', 'Ahrweiler Markt', 'Aichach', 'Aichstetten', 'Ainring', 'Albbruck', 'Albersdorf', 'Albersweiler (Pfalz)', 'Albig', 'Albrechtshof', 'Albshausen', 'Albsheim (Eis)', 'Albstadt Ebingen West', 'Albstadt-Ebingen', 'Albstadt-Laufen Ort', 'Albstadt-Lautlingen', 'Aldekerk', 'Aldingen', 'Aletshausen', 'Alexanderplatz', 'Alfeld (Leine)', 'Alfter-Impekoven', 'Alfter-Witterschlick', 'Algermissen', 'Alheim-Heinebach', 'Aligse', 'Allee-Center Leipzig', 'Allendorf (Dillkreis)', 'Allensbach', 'Allermöhe', 'Allersberg (Rothsee)', 'Allmendingen', 'Alpen', 'Alpirsbach', 'Alsenz', 'Alsfeld (Oberhessen)', 'Alsheim', 'Alt Hüttendorf', 'Alt Rosenthal', 'Alt-Reinickendorf', 'Altbach', 'Altdöbern', 'Altdorf (Nürnberg)', 'Altdorf West', 'Alte Veste', 'Alte Wöhr', 'Altefähr', 'Altena (Westfalen)', 'Altenahr', 'Altenau (Bayern)', 'Altenbach', 'Altenbamberg', 'Altenbeken', 'Altenberge', 'Altenburg', 'Altenerding', 'Altenfeld (Rhön)', 'Altenglan', 'Altengörs', 'Altenkirchen (Westerwald)', 'Altenseelbach', 'Altenstadt (Hessen)', 'Altenstadt (Iller)', 'Altenstadt (Waldnaab)', 'Altenstadt-Höchst', 'Altenstadt-Lindheim', 'Altentreptow', 'Altenwillershagen', 'Altersbach', 'Altes Lager', 'Altglashütten-Falkau', 'Altglienicke', 'Althegnenberg', 'Altheim (Hessen)', 'Althof', 'Altmittweida', 'Altomünster', 'Altranft', 'Altshausen', 'Altstädten (Allgäu)', 'Alttann', 'Alzey', 'Alzey Süd', 'Amberg', 'Ammern', 'Ampfing', 'Amsdorf', 'Amstetten (Württemberg)', 'Amtshainersdorf', 'Andernach', 'Anderten-Misburg', 'Angermund', 'Angermünde', 'Angern-Rogätz', 'Angersbach', 'Angersdorf', 'Anklam', 'Annaburg', 'Annweiler am Trifels', 'Annweiler-Sarnstall', 'Anrath', 'Ansbach', 'Anwanden', 'Anzefahr', 'Apolda', 'Appenweier', 'Ardey', 'Arensdorf (Köthen)', 'Arenshausen', 'Arfurt (Lahn)', 'Armsheim', 'Arnbach', 'Arnsberg (Westfalen)', 'Arnsberg-Neheim-Hüsten', 'Arnschwang', 'Arnsdorf (Dresden)', 'Arnstadt Hauptbahnhof', 'Arnstadt Süd', 'Arsbeck', 'Artern', 'Arzberg (Oberfr)', 'Aschaffenburg Hauptbahnhof', 'Aschaffenburg Hochschule', 'Aschaffenburg Süd', 'Aschau (Chiemgau)', 'Ascheberg (Holstein)', 'Ascheberg (Westfalen)', 'Aschendorf', 'Aschersleben', 'Ashausen', 'Asperg', 'Asselheim', 'Assenheim (Oberhessen)', 'Aßlar', 'Aßling (Oberbayern)', 'Assmannshausen', 'Attendorn', 'Attendorn Hohen-Hagen', 'Attilastraße', 'Au (Sieg)', 'Aue-Wingeshausen', 'Auehütte', 'Auerbach (Mosbach)', 'Auerbach (Vogtland)', 'Auerbach (Vogtland) oberer Bahnhof', 'Auerbach (Vogtland) unterer Bahnhof', 'Auersmacher', 'Auerstedt', 'Aufhausen (Erding)', 'Aufhausen (Württemberg)', 'Auggen', 'Augsburg Haunstetterstraße', 'Augsburg Hauptbahnhof', 'Augsburg Messe', 'Augsburg Morellstraße', 'Augsburg-Hochzoll', 'Augsburg-Oberhausen', 'Augustfehn', 'Aukrug', 'Aulendorf', 'Aumenau', 'Aumühle', 'Auringen-Medenbach', 'Außenried', 'Auw an der Kyll', 'Aying', 'Baalberge', 'Baar-Ebenhausen', 'Babelsberg', 'Babenhausen (Hessen)', 'Babenhausen Langstadt', 'Babstadt', 'Bacharach', 'Bachern', 'Bachfeld', 'Bachheim', 'Backnang', 'Bad Abbach', 'Bad Aibling', 'Bad Aibling Kurpark', 'Bad Bellingen', 'Bad Belzig', 'Bad Bentheim', 'Bad Bergzabern', 'Bad Berka', 'Bad Berka Zeughausplatz', 'Bad Berleburg', 'Bad Bevensen', 'Bad Blankenburg (Thüringer Wald)', 'Bad Bodendorf', 'Bad Bodenteich', 'Bad Brambach', 'Bad Breisig', 'Bad Camberg', 'Bad Doberan', 'Bad Driburg (Westfalen)', 'Bad Dürkheim', 'Bad Dürkheim-Trift', 'Bad Dürrenberg', 'Bad Elster', 'Bad Ems', 'Bad Ems West', 'Bad Endorf (Oberbayern)', 'Bad Fallingbo ...

# %% [markdown]
# There is a lot of train stations in Germany so feel free to choose on of them.

# %%
while True:
    station = input("Select available station")
    if str(station) in stations_dictionary:
        print("Successfully selected station")
        break
    else:
        print("Selected station is not available. Try again.") 
        continue
# Out:
# Successfully selected station

# %% [markdown]
# Now we will connect to site preseting informations about choosen train station.

# %%
website = stations_dictionary[str(station)]
driver.get(str(website))

# %% [markdown]
# At the beggining we need to accept cookies by clicking the button.

# %%
cookie_button = driver.find_element_by_xpath('//*[@id="BorlabsCookieBox"]/div/div/div/div[1]/div/div/div[2]/p[1]/a')
driver.execute_script("arguments[0].click();", cookie_button)

# %% [markdown]
# As you can see by default website present only 10 rows in each table. Let's change it to display 100 rows.

# %%
for table in ["DataTables_Table_0_length", "DataTables_Table_1_length"]:
    dropdown_button = driver.find_element_by_name(table)
    dropdown_button.click()
    select_dropdown = Select(dropdown_button)
    select_dropdown.select_by_index(3)

# %% [markdown]
# Now is time to design how our scraped table should look like.

# %%
arrivals = pd.DataFrame(columns=["Line", "From", "To", "Delay", "Hour", "Minute", "Day", "Day of Year", "Weekday","Week number", "Month", "Year"])
departures = pd.DataFrame(columns=["Line", "From", "To", "Delay", "Hour", "Minute", "Day", "Day of Year", "Weekday","Week number", "Month", "Year"])

# %% [markdown]
# This code scraps informations from each table, adds some time informations and store them in dataframes.

# %%
time = datetime.datetime.now()

for dataset in ["DataTables_Table_0", "DataTables_Table_1"]:
    table = driver.find_element_by_id(dataset) 
    trs = table.find_elements_by_tag_name("tr")
    for tr in trs:
        lst = []
        tds = tr.find_elements_by_tag_name("td")
        for td in tds:
            lst.append(td.text)
        if len(lst) == 0:
            continue
        else:
            if dataset == "DataTables_Table_0":
                departures = pd.concat([departures, pd.DataFrame({"Line" : lst[0], "From" : lst[2], "To" : lst[3], "Delay" : lst[5], "Hour": lst[1][:2], "Minute": lst[1][3:5], "Day" : time.strftime("%d"), "Day of Year" : time.strftime("%j"), "Weekday" : time.strftime("%w"), "Week number" : time.strftime("%W"), "Month": time.strftime("%m"), "Year" : time.strftime("%Y")}, index = [0])], ignore_index=True)
            elif dataset == "DataTables_Table_1":
                arrivals = pd.concat([arrivals, pd.DataFrame({"Line" : lst[0], "From" : lst[2], "To" : lst[3], "Delay" : lst[5], "Hour": lst[1][:2], "Minute": lst[1][3:5], "Day" : time.strftime("%d"), "Day of Year" : time.strftime("%j"), "Weekday" : time.strftime("%w"), "Week number" : time.strftime("%W"), "Month": time.strftime("%m"), "Year" : time.strftime("%Y")}, index = [0])], ignore_index=True)

# %% [markdown]
# As you can see if connection is delayed its represented as "+(minutes_of_delay)" otherwise there's an empty string. Let's change it to display delay as integer. At the end we can also set datatypes in dataframe to corresponds to data each column stores.

# %%
for dataset in [departures, arrivals]:
    dataset.Delay = dataset.Delay.apply(lambda x : 0 if x == "" else x.lstrip("+"))
    dataset = dataset.astype({"Delay" : "int64" , "Hour": "int64", "Minute": "int64", "Day" : "int64", "Day of Year" : "int64", "Weekday" : "int64", "Week number" :"int64", "Month": "int64", "Year" : "int64"})

# %% [markdown]
# Take a look at Departures scraped table.

# %%
departures
# Out:
#         Line          From     To Delay Hour Minute Day Day of Year Weekday  \
# 0   OPB RB95       Hof Hbf  Rehau     1   11     23  05         248       2
# 1    ag RB96       Hof Hbf  Rehau     0   11     54  05         248       2
# 2    ag RB96    Selb Stadt  Rehau     0   11     54  05         248       2
# 3   OPB RB95  Marktredwitz  Rehau     0   12     28  05         248       2
# 4    ag RB96    Selb Stadt  Rehau     0   12     54  05         248       2
# 5    ag RB96       Hof Hbf  Rehau     0   12     54  05         248       2
# 6   OPB RB95       Hof Hbf  Rehau     0   13     22  05         248       2
# 7    ag RB96    Selb Stadt  Rehau     0   13     54  05         248       2
# 8    ag RB96       Hof Hbf  Rehau     0   13     56  05         248       2
# 9   OPB RB95  Marktredwitz  Rehau     0   14     28  05         248       2
# 10   ag RB96    Selb Stadt  Rehau     0   14     54  05         248       2
# 11   ag RB96       Hof Hbf  Rehau     0   14     54  05         248       2
# 12  OPB RB95       Hof Hbf  Rehau     0   15     22  05         248       2
# 13   ag RB96    Selb Stadt  Rehau     0   15     54  05         248       2
# 14   ag RB96       Hof Hbf  Rehau     0   15     54  05         248       2
# 15  OPB RB95  Marktredwitz  Rehau     0   16     28  05         248       2
# 16   ag RB96    Selb Stadt  Rehau     0   16     54  05         248       2
# 17   ag RB96       Hof Hbf  Rehau     0   16     54  05         248       2
# 18  OPB RB95       Hof Hbf  Rehau     0   17     22  05         248       2
# 19   ag RB96    Selb Stadt  Rehau     0   17     54  05         248       2
# 20   ag RB96       Hof Hbf  Rehau     0   17     54  05         248       2
# 21  OPB RB95  Marktredwitz  Rehau     0   18     28  05         248       2
# 22   ag RB96    Selb Stadt  Rehau     0   18     54  05         248       2
# 23   ag RB96       Hof Hbf  Rehau     0   18     54  05         248       2
# 24  OPB RB95       Hof Hbf  Rehau     0   19     22  05         248       2
# 25   ag RB96       Hof Hbf  Rehau     0   19     54  05         248       2
# 26   ag RB96    Selb Stadt  Rehau     0   19     54  05         248       2
# 27  OPB RB95  Marktredwitz  Rehau     0   20     28  05         248       2
# 28   ag RB96    Selb Stadt  Rehau     0   20     54  05         248       2
# 29   ag RB96       Hof Hbf  Rehau     0   20     54  05         248       2
# 30   ag RB96    Selb Stadt  Rehau     0   21     54  05         248       2
# 31   ag RB96       Hof Hbf  Rehau     0   21     54  05         248       2
# 32  OPB RB95       Hof Hbf  Rehau     0   22     58  05         248       2
#
#    Week number Month  Year
# 0           36    09  2023
# 1           36    09  2023
# 2           36    09  2023
# 3           36    09  2023
# 4           36    09  2023
# 5           36    09  2023
# 6           36    09  2023
# 7           36    09  2023
# 8           36    09  2023
# 9           36    09  2023
# 10          36    09  2023
# 11          36    09  2023
# 12          36    09  2023
# 13          36    09  2023
# 14          36    09  2023
# 15          36    09  2023
# 16          36    09  2023
# 17          36    09  2023
# 18          36    09  2023
# 19          36    09  2023
# 20          36    09  2023
# 21          36    09  2023
# 22          36    09  2023
# 23          36    09  2023
# 24          36    09  2023
# 25          36    09  2023
# 26          36    09  2023
# 27          36    09  2023
# 28          36    09  2023
# 29          36    09  2023
# 30          36    09  2023
# 31          36    09  2023
# 32          36    09  2023

# %% [markdown]
# Here are Arrivals.

# %%
arrivals
# Out:
#         Line   From            To Delay Hour Minute Day Day of Year Weekday  \
# 0   OPB RB95  Rehau  Marktredwitz     1   11     23  05         248       2
# 1    ag RB96  Rehau       Hof Hbf     0   11     55  05         248       2
# 2    ag RB96  Rehau    Selb Stadt     0   11     56  05         248       2
# 3   OPB RB95  Rehau       Hof Hbf     0   12     28  05         248       2
# 4    ag RB96  Rehau       Hof Hbf     0   12     55  05         248       2
# 5    ag RB96  Rehau    Selb Stadt     0   12     56  05         248       2
# 6   OPB RB95  Rehau  Marktredwitz     0   13     22  05         248       2
# 7    ag RB96  Rehau       Hof Hbf     0   13     57  05         248       2
# 8    ag RB96  Rehau    Selb Stadt     0   13     58  05         248       2
# 9   OPB RB95  Rehau       Hof Hbf     0   14     28  05         248       2
# 10   ag RB96  Rehau       Hof Hbf     0   14     55  05         248       2
# 11   ag RB96  Rehau    Selb Stadt     0   14     56  05         248       2
# 12  OPB RB95  Rehau  Marktredwitz     0   15     22  05         248       2
# 13   ag RB96  Rehau       Hof Hbf     0   15     55  05         248       2
# 14   ag RB96  Rehau    Selb Stadt     0   15     56  05         248       2
# 15  OPB RB95  Rehau       Hof Hbf     0   16     28  05         248       2
# 16   ag RB96  Rehau       Hof Hbf     0   16     55  05         248       2
# 17   ag RB96  Rehau    Selb Stadt     0   16     56  05         248       2
# 18  OPB RB95  Rehau  Marktredwitz     0   17     22  05         248       2
# 19   ag RB96  Rehau       Hof Hbf     0   17     55  05         248       2
# 20   ag RB96  Rehau    Selb Stadt     0   17     56  05         248       2
# 21  OPB RB95  Rehau       Hof Hbf     0   18     28  05         248       2
# 22   ag RB96  Rehau       Hof Hbf     0   18     55  05         248       2
# 23   ag RB96  Rehau    Selb Stadt     0   18     56  05         248       2
# 24  OPB RB95  Rehau  Marktredwitz     0   19     22  05         248       2
# 25   ag RB96  Rehau       Hof Hbf     0   19     55  05         248       2
# 26   ag RB96  Rehau    Selb Stadt     0   19     56  05         248       2
# 27  OPB RB95  Rehau       Hof Hbf     0   20     28  05         248       2
# 28   ag RB96  Rehau       Hof Hbf     0   20     55  05         248       2
# 29   ag RB96  Rehau    Selb Stadt     0   20     56  05         248       2
# 30   ag RB96  Rehau       Hof Hbf     0   21     55  05         248       2
# 31   ag RB96  Rehau    Selb Stadt     0   21     56  05         248       2
# 32  OPB RB95  Rehau        As(CZ)     0   22     59  05         248       2
#
#    Week number Month  Year
# 0           36    09  2023
# 1           36    09  2023
# 2           36    09  2023
# 3           36    09  2023
# 4           36    09  2023
# 5           36    09  2023
# 6           36    09  2023
# 7           36    09  2023
# 8           36    09  2023
# 9           36    09  2023
# 10          36    09  2023
# 11          36    09  2023
# 12          36    09  2023
# 13          36    09  2023
# 14          36    09  2023
# 15          36    09  2023
# 16          36    09  2023
# 17          36    09  2023
# 18          36    09  2023
# 19          36    09  2023
# 20          36    09  2023
# 21          36    09  2023
# 22          36    09  2023
# 23          36    09  2023
# 24          36    09  2023
# 25          36    09  2023
# 26          36    09  2023
# 27          36    09  2023
# 28          36    09  2023
# 29          36    09  2023
# 30          36    09  2023
# 31          36    09  2023
# 32          36    09  2023

# %% [markdown]
# It's time to save this dataframes into csv files. Before that we need to make sure that name of csv is proper. Some names of stations have space so the first thing is to change them to underscore sign. The name of files will be as follows : "Departures/Arrivals_Station_Hour_Minute_Day_Month_Year.csv"

# %%
station = station.replace(" ", "_")
departures_filename = "Departures" + "_" + station + "_" + str(time.strftime("%H_%M_%d_%m_%Y")) + ".csv"
departures.to_csv(departures_filename)
arrivals_filename = "Arrivals" + "_" + station + "_" + str(time.strftime("%H_%M_%d_%m_%Y")) + ".csv"
arrivals.to_csv(arrivals_filename)

# %% [markdown]
# In the end we are disconnecting from website.

# %%
driver.quit()
